# %% [markdown]
# # Corner statistics visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Main statistics

# %% [markdown]
# ### Warmup with common deviations

# %%
plt.imshow(plt.imread("plots/mean_max_min_deviations_plot.png"))

# %%
plt.imshow(plt.imread("plots/ceiling_deviations_plot.png"))

# %%
plt.imshow(plt.imread("plots/floor_deviations_plot.png"))

# %% [markdown]
# ### Let's look on floor vs ceiling deviations

# %% [markdown]
# #### Max case

# %%
plt.imshow(plt.imread("plots/floor_max_vs_ceiling_max_correlation_plot.png"))

# %% [markdown]
# #### Mean case

# %%
plt.imshow(plt.imread("plots/floor_mean_vs_ceiling_mean_correlation_plot.png"))

# %% [markdown]
# #### Min case

# %%
plt.imshow(plt.imread("plots/floor_min_vs_ceiling_min_correlation_plot.png"))

# %% [markdown]
# #### Conlusion
# It looks like the deviation in the corners of the ceilings is greater than that of the floors

# %% [markdown]
# ### Analyze ground truth vs model corners

# %%
plt.imshow(plt.imread("plots/ground_truth_vs_model_corners_plot.png"))

# %% [markdown]
# #### Conclusion
# It looks like model predictions about number of corners are correct.

# %% [markdown]
# ### Attempt to finc relationship between number of corners and mean deviations

# %%
plt.imshow(plt.imread("plots/gt_corners_vs_ceiling_mean_deviation_correlation_plot.png"))

# %%
plt.imshow(plt.imread("plots/gt_corners_vs_floor_mean_deviation_correlation_plot.png"))

# %%
plt.imshow(plt.imread("plots/gt_corners_vs_mean_deviation_correlation_plot.png"))

# %% [markdown]
# #### Conclusion
# At first glance it may seem that the more corners, the greater the deviation. But the number of rooms with 8 and 10 corners is too small compared to the number of rooms with 4 corners:(

# %% [markdown]
# ## Conclusion
# For a more detailed analysis, it would be great to know a little more data about your model
#
# P.S. Thank you for the opportunity!
